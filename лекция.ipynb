# %%
a = input("Введите число a")
print(a)
# Out:
# Введите число a54
# 54

# %%
ages = [16, 16, 26 , 15, 16, 17]

for age in ages:
  if age >= 16:
    print(age)
# Out:
# 16
# 16
# 26
# 16
# 17

# %%
letters = list("Matvey")
print(letters)
# Out:
# ['M', 'a', 't', 'v', 'e', 'y']

# %%
print(letters[0])
print(letters[-1])
# Out:
# M
# y

# %%
name = input("Input your name: ")
name = list(name)

print(name[0])
name[-1] = name[-1]. upper()
print(name[-1])
# Out:
# Input your name: Matvey
# M
# Y

# %%
people = ["Tom", "Sam", "Bob"]
i = 0
while i < len(people):
  print(people[i])
  i += 1
# Out:
# Tom
# Sam
# Bob

# %%
people = "MatveyTkachev"

slice_people1 = people[:3]
print(slice_people1)

slice_people2 = people[1:3]
print(slice_people2)

slice_people3 = people[1:6:2]
print(slice_people3)
# Out:
# Mat
# at
# avy
